# %%
# import libraries
import pandas as pd
import numpy
import sklearn.neighbors._base
import sys
sys.modules['sklearn.neighbors.base'] = sklearn.neighbors._base
import missingpy

# %%
# mount google drive 
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# load google drive csv file
df = pd.read_csv("/content/drive/MyDrive/Statistics Project 2/Data/Raw/landfillData_NEW.csv")

# %%
df
# Out:
#          Index      emissionsTS emissiondate emissiontime   CH4   CO2   O2  \
# 0            0    9/1/2020 0:02     9/1/2020      0:02:18  34.3  28.9  0.2
# 1            1    9/1/2020 0:12     9/1/2020      0:12:18  34.4  28.9  0.2
# 2            2    9/1/2020 0:22     9/1/2020      0:22:19  34.4  29.0  0.6
# 3            3    9/1/2020 0:32     9/1/2020      0:32:19  34.5  29.0  0.3
# 4            4    9/1/2020 0:42     9/1/2020      0:42:19  34.5  29.0  0.2
# ...        ...              ...          ...          ...   ...   ...  ...
# 101161  101161  9/22/2022 15:33    9/22/2022     15:33:29  47.2  32.5  0.0
# 101162  101162  9/22/2022 15:43    9/22/2022     15:43:29  47.3  32.4  0.0
# 101163  101163  9/22/2022 15:53    9/22/2022     15:53:30  47.3  32.4  0.0
# 101164  101164  9/22/2022 16:03    9/22/2022     16:03:30  47.3  32.4  0.0
# 101165  101165  9/22/2022 16:08    9/22/2022     16:08:38  47.3  32.4  0.0
#
# ...

# %%
# missingpy does not take any string type so will temporarily remove
#inserted back with excel
df = df.drop(['Index','emissionsTS', 'emissiondate', 'emissiontime', 'weatherTS', 'weatherDate', 'weatherTime','conditions'], axis=1)

# %%
df
# Out:
#          Index   CH4   CO2   O2  otherGas  internalPressure_Hg  fau_degF  \
# 0            0  34.3  28.9  0.2      36.6                29.25      88.2
# 1            1  34.4  28.9  0.2      36.5                29.25      88.1
# 2            2  34.4  29.0  0.6      36.0                29.25      88.3
# 3            3  34.5  29.0  0.3      36.2                29.25      88.1
# 4            4  34.5  29.0  0.2      36.3                29.25      88.4
# ...        ...   ...   ...  ...       ...                  ...       ...
# 101161  101161  47.2  32.5  0.0      20.3                29.18      86.4
# 101162  101162  47.3  32.4  0.0      20.3                29.18      86.6
# 101163  101163  47.3  32.4  0.0      20.3                29.18      86.4
# 101164  101164  47.3  32.4  0.0      20.3                29.18      86.4
# 101165  101165  47.3  32.4  0.0      20.3                  NaN       NaN
#
#         flowMain_SCFM  tempdegf   dew  humidity  precip  windspeed  \
# ...

# %%
#beging imputation using random forest
from missingpy import MissForest
imputer = MissForest()
df_new = imputer.fit_transform(df)
# Out:
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# ...

# %%
# change from array to DataFrame type
# save as csv
th = pd.DataFrame(df_new)
th.to_csv('imputed.csv', sep =',')
